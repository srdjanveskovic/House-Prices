# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
train = pd.read_csv('train.csv')

# %%
train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
train.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
test = pd.read_csv('test.csv')

# %%
test.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence MiscFeature  \
# 0         Lvl    AllPub  ...         120        0    NaN  MnPrv         NaN
# 1         Lvl    AllPub  ...           0        0    NaN    NaN        Gar2
# 2         Lvl    AllPub  ...           0        0    NaN  MnPrv         NaN
# 3         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 4         HLS    AllPub  ...         144        0    NaN    NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
plt.figure(figsize = (15,7))
sns.heatmap(train.corr())
# Out:
# <AxesSubplot:>

# %%
# GrLivArea: Above grade (ground) living area square feet
train.drop('SalePrice', axis = 1).corrwith(train['SalePrice']).sort_values(ascending = False)
# Out:
# OverallQual      0.790982
# GrLivArea        0.708624
# GarageCars       0.640409
# GarageArea       0.623431
# TotalBsmtSF      0.613581
# 1stFlrSF         0.605852
# FullBath         0.560664
# TotRmsAbvGrd     0.533723
# YearBuilt        0.522897
# YearRemodAdd     0.507101
# GarageYrBlt      0.486362
# MasVnrArea       0.477493
# Fireplaces       0.466929
# BsmtFinSF1       0.386420
# LotFrontage      0.351799
# WoodDeckSF       0.324413
# 2ndFlrSF         0.319334
# OpenPorchSF      0.315856
# HalfBath         0.284108
# LotArea          0.263843
# BsmtFullBath     0.227122
# BsmtUnfSF        0.214479
# BedroomAbvGr     0.168213
# ScreenPorch      0.111447
# PoolArea         0.092404
# MoSold           0.046432
# 3SsnPorch        0.044584
# BsmtFinSF2      -0.011378
# BsmtHalfBath    -0.016844
# MiscVal         -0.021190
# Id              -0.021917
# LowQualFinSF    -0.025606
# YrSold          -0.028923
# OverallCond     -0.077856
# MSSubClass      -0.084284
# ...

# %%
train.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
clear_data = [train, test]

# %%
sns.countplot(train['OverallQual'])
# Out:
# <AxesSubplot:xlabel='OverallQual', ylabel='count'>

# %%
#Since we don't need 'Id' columns for prediction we will remove them 
test_id = test['Id']

# %%
train = train.drop('Id',axis=1)
test = test.drop('Id',axis=1)

# %%
from scipy.stats import norm
from sklearn.preprocessing import StandardScaler
from scipy import stats

# %%
sns.histplot(train['SalePrice'])
# Out:
# <AxesSubplot:xlabel='SalePrice', ylabel='Count'>

# %%
train.corr().nlargest(10, 'SalePrice')['SalePrice'].index
# Out:
# Index(['SalePrice', 'OverallQual', 'GrLivArea', 'GarageCars', 'GarageArea',
#        'TotalBsmtSF', '1stFlrSF', 'FullBath', 'TotRmsAbvGrd', 'YearBuilt'],
#       dtype='object')

# %%
cols = train.corr().nlargest(10, 'SalePrice').index

# %%
plt.figure(figsize=(19,12))
sns.heatmap(train[cols].corr().nlargest(10, 'SalePrice'), annot = True, square = True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here we can see a multicolinearity between GarageArea and GarageCars (0.88), which is logical.
# So, to prevent multicolinearity, we will take into account only one of them, which will be a GarageCars, because it has a little higher dependency on SalePrice.
# Also, we have 1stFlrSF and TotalBsmtSF(0.82), so we can pick either to retain in our research. Let's say TotalBsmtSF.
# Lastly, we will exclude TotRmsAbvGrd because of its strong correlation with GrLivArea(0.83).

# %%
cols_new = cols.drop(['GarageArea', '1stFlrSF','TotRmsAbvGrd'])

# %%
sns.pairplot(data = train[cols_new])

# %%
# Percentage of missing data in a column
df_missing = pd.concat([train.isnull().sum().sort_values(ascending = False),
                        (train.isnull().sum().sort_values(ascending = False)/ train.isnull().count())], axis=1, names = [2,1])

# %%
df_missing.columns = ['Total', 'Percentage']
df_missing.sort_values(by = 'Total', ascending = False).head(20)
# Out:
#               Total  Percentage
# PoolQC         1453    0.995205
# MiscFeature    1406    0.963014
# Alley          1369    0.937671
# Fence          1179    0.807534
# FireplaceQu     690    0.472603
# LotFrontage     259    0.177397
# GarageYrBlt      81    0.055479
# GarageCond       81    0.055479
# GarageFinish     81    0.055479
# GarageQual       81    0.055479
# GarageType       81    0.055479
# BsmtExposure     38    0.026027
# BsmtFinType2     38    0.026027
# BsmtCond         37    0.025342
# BsmtQual         37    0.025342
# BsmtFinType1     37    0.025342
# MasVnrType        8    0.005479
# MasVnrArea        8    0.005479
# Electrical        1    0.000685
# BldgType          0    0.000000

# %% [markdown]
# We will consider that when more than 15% of data is missing, we should delete the corresponding variable.
# In other cases, we have 'Garage' types of data, which we also may exclude due to the fact we have GarageCars column.
# Same goes with the other 'Bsmt' columns.
# Regarding 'MasVnrArea' and 'MasVnrType' we can consider these as not essential. And also they have high correlation with 'YearBuilt' and 'OverallQual' which are already considered.
# Finally, we have one missing in 'Electrical'. Since it's just one, we can delete this one observation.

# %%
df_missing_test = pd.concat([test.isnull().sum().sort_values(ascending = False),
                        (test.isnull().sum().sort_values(ascending = False)/ test.isnull().count())], axis=1, names = [2,1])
df_missing_test.columns = ['Total', 'Percentage']
df_missing_test.sort_values(by = 'Total', ascending = False).head(35)
# Out:
#               Total  Percentage
# PoolQC         1456    0.997944
# MiscFeature    1408    0.965045
# Alley          1352    0.926662
# Fence          1169    0.801234
# FireplaceQu     730    0.500343
# LotFrontage     227    0.155586
# GarageYrBlt      78    0.053461
# GarageFinish     78    0.053461
# GarageQual       78    0.053461
# GarageCond       78    0.053461
# GarageType       76    0.052090
# BsmtCond         45    0.030843
# BsmtExposure     44    0.030158
# BsmtQual         44    0.030158
# BsmtFinType1     42    0.028787
# BsmtFinType2     42    0.028787
# MasVnrType       16    0.010966
# MasVnrArea       15    0.010281
# MSZoning          4    0.002742
# Functional        2    0.001371
# BsmtHalfBath      2    0.001371
# BsmtFullBath      2    0.001371
# Utilities         2    0.001371
# TotalBsmtSF       1    0.000685
# BsmtFinSF2        1    0.000685
# GarageArea        1    0.000685
# Exterior1st       1    0.000685
# Exterior2nd       1    0.000685
# ...

# %%
df_missing_test[df_missing_test['Total'] > 0].count()
# Out:
# Total         33
# Percentage    33
# dtype: int64

# %%
df_missing[df_missing['Total'] > 0].count()
# Out:
# Total         19
# Percentage    19
# dtype: int64

# %%
test = test.drop(df_missing_test[df_missing_test['Total'] > 10].index, axis = 1)

# %%
train = train.drop(df_missing[df_missing['Total'] > 1].index, axis = 1)

# %%
train = train.drop(train.loc[train['Electrical'].isnull()].index)

# %%
# Now we have no missing data in train
train.isnull().sum().max()
# Out:
# 0

# %%
test.isnull().sum().sort_values(ascending = False).head(15)
# Out:
# MSZoning        4
# Functional      2
# BsmtFullBath    2
# BsmtHalfBath    2
# Utilities       2
# BsmtFinSF2      1
# Exterior2nd     1
# GarageCars      1
# GarageArea      1
# BsmtFinSF1      1
# BsmtUnfSF       1
# KitchenQual     1
# TotalBsmtSF     1
# SaleType        1
# Exterior1st     1
# dtype: int64

# %%
cols = test.isnull().sum().sort_values(ascending = False).head(15).index

# %%
for col in cols:
    test.loc[test[col].isnull(), col] = test[col].mode()[0]

# %%
test.isnull().sum().sort_values(ascending = False).max()
# Out:
# 0

# %%
test.shape
# Out:
# (1459, 61)

# %%
train.columns.difference(test.columns)
# Out:
# Index(['SalePrice'], dtype='object')

# %%
train.shape
# Out:
# (1459, 62)

# %%
# We deal with outliers
sns.scatterplot(x='GrLivArea', y='SalePrice', data = train)
# Out:
# <AxesSubplot:xlabel='GrLivArea', ylabel='SalePrice'>

# %%
# We can see two highest GrLivArea values on the right that are like special case, thus, not following trend at all.
# So we shall delete those.
train = train.drop(train.sort_values(by = 'GrLivArea', ascending = False)[:2].index)

# %%
sns.scatterplot(x='GrLivArea', y='SalePrice', data = train)
# Out:
# <AxesSubplot:xlabel='GrLivArea', ylabel='SalePrice'>

# %%
# We could delete TotalBsmtSF > 3000 but seems like we could with that data.
sns.scatterplot(x='TotalBsmtSF', y='SalePrice', data = train)
# Out:
# <AxesSubplot:xlabel='TotalBsmtSF', ylabel='SalePrice'>

# %%
fig, ax = plt.subplots(1,2, figsize=(16,4))
sns.distplot(train['SalePrice'], fit = norm, ax = ax[0])

stats.probplot(train['SalePrice'], plot= ax[1])
# Out:
# ((array([-3.30456314, -3.04731426, -2.90425334, ...,  2.90425334,
#           3.04731426,  3.30456314]),
#   array([ 34900,  35311,  37900, ..., 625000, 745000, 755000], dtype=int64)),
#  (74240.99917988208, 180942.13864104328, 0.9320520365889888))

# %%
# There is 'peakedness' and positive skewness in SalePrice.
# Data transformation is needed.
# In case of positive skewness, logarithm transformation could work.
train['SalePrice'] = np.log(train['SalePrice'])

# %%
fig, ax = plt.subplots(1,2, figsize=(16,4))
sns.distplot(train['SalePrice'], fit = norm, ax = ax[0])
stats.probplot(train['SalePrice'], plot= ax[1])
# Out:
# ((array([-3.30456314, -3.04731426, -2.90425334, ...,  2.90425334,
#           3.04731426,  3.30456314]),
#   array([10.46024211, 10.47194981, 10.54270639, ..., 13.34550693,
#          13.5211395 , 13.53447303])),
#  (0.3986736383757875, 12.024005414589174, 0.9954027633642688))

# %%
fig, ax = plt.subplots(1,2, figsize=(16,4))
sns.distplot(train['GrLivArea'], fit = norm, ax = ax[0])
stats.probplot(train['GrLivArea'], plot= ax[1])
# Out:
# ((array([-3.30456314, -3.04731426, -2.90425334, ...,  2.90425334,
#           3.04731426,  3.30456314]),
#   array([ 334,  438,  480, ..., 3627, 4316, 4476], dtype=int64)),
#  (495.86487962489497, 1510.5456417295816, 0.9744141158065246))

# %%
# Again positive skewness
train['GrLivArea'] = np.log(train['GrLivArea'])
test['GrLivArea'] = np.log(test['GrLivArea'])

# %%
# This is better now
fig, ax = plt.subplots(1,2, figsize=(16,4))
sns.distplot(train['GrLivArea'], fit = norm, ax = ax[0])
stats.probplot(train['GrLivArea'], plot= ax[1])
# Out:
# ((array([-3.30456314, -3.04731426, -2.90425334, ...,  2.90425334,
#           3.04731426,  3.30456314]),
#   array([5.81114099, 6.08221891, 6.1737861 , ..., 8.19616114, 8.37008433,
#          8.40648507])),
#  (0.3304288478350053, 7.266041506402603, 0.9981242998055863))

# %%
# What we have here is a significant number of observations with value of zero (without basement)
# We can't perform log transformation on zero values
fig, ax = plt.subplots(1,2, figsize=(16,4))
sns.distplot(train['TotalBsmtSF'], fit = norm, ax = ax[0])
stats.probplot(train['TotalBsmtSF'], plot= ax[1])
# Out:
# ((array([-3.30456314, -3.04731426, -2.90425334, ...,  2.90425334,
#           3.04731426,  3.30456314]),
#   array([   0,    0,    0, ..., 3094, 3200, 3206], dtype=int64)),
#  (408.0232985397026, 1052.995881949211, 0.9821435933722061))

# %%
# We could create a variable which tells us whether the house has basement or not
# and then we perform log transform on all non-zero values
train['Has_Bsmt'] = 0
train.loc[train['TotalBsmtSF'] > 0, 'Has_Bsmt'] = 1
test['Has_Bsmt'] = 0
test.loc[test['TotalBsmtSF'] > 0, 'Has_Bsmt'] = 1

# %%
test['Has_Bsmt'].value_counts()
# Out:
# 1    1417
# 0      42
# Name: Has_Bsmt, dtype: int64

# %%
train['Has_Bsmt'].value_counts()
# Out:
# 1    1420
# 0      37
# Name: Has_Bsmt, dtype: int64

# %%
train.loc[train['Has_Bsmt'] == 1, 'TotalBsmtSF'] = np.log(train['TotalBsmtSF'])
test.loc[test['Has_Bsmt'] == 1, 'TotalBsmtSF'] = np.log(test['TotalBsmtSF'])

# %%
# Not sure it's all right that we exclude all zeroes from a normal distribution
fig, ax = plt.subplots(1,2, figsize=(16,4))
sns.distplot(train[train['TotalBsmtSF']>0]['TotalBsmtSF'], fit = norm, ax = ax[0])
stats.probplot(train[train['TotalBsmtSF']>0]['TotalBsmtSF'], plot= ax[1])
# Out:
# ((array([-3.29734785, -3.03957662, -2.89619317, ...,  2.89619317,
#           3.03957662,  3.29734785]),
#   array([4.65396035, 5.24702407, 5.5759491 , ..., 8.03722003, 8.07090609,
#          8.07277933])),
#  (0.35386497225381236, 6.923661865160317, 0.9912372939608375))

# %%
#train = pd.get_dummies(train)

# %%
train.shape
# Out:
# (1457, 63)

# %%
train = pd.get_dummies(train)

# %%
test = pd.get_dummies(test)

# %%
train.shape
# Out:
# (1457, 221)

# %%
test.shape
# Out:
# (1459, 206)

# %%
train.columns.difference(test.columns)
# Out:
# Index(['Condition2_RRAe', 'Condition2_RRAn', 'Condition2_RRNn',
#        'Electrical_Mix', 'Exterior1st_ImStucc', 'Exterior1st_Stone',
#        'Exterior2nd_Other', 'Heating_Floor', 'Heating_OthW',
#        'HouseStyle_2.5Fin', 'RoofMatl_Membran', 'RoofMatl_Metal',
#        'RoofMatl_Roll', 'SalePrice', 'Utilities_NoSeWa'],
#       dtype='object')

# %%
SalePrice = train['SalePrice']

# %%
SalePrice
# Out:
# 0       12.247694
# 1       12.109011
# 2       12.317167
# 3       11.849398
# 4       12.429216
#           ...
# 1455    12.072541
# 1456    12.254863
# 1457    12.493130
# 1458    11.864462
# 1459    11.901583
# Name: SalePrice, Length: 1457, dtype: float64

# %%
train = train.drop(train.columns.difference(test.columns), axis = 1)

# %%
test.shape
# Out:
# (1459, 206)

# %%
train.shape
# Out:
# (1457, 206)

# %%
y_train = SalePrice

# %% [markdown]
# # Modelling

# %%
from sklearn.linear_model import ElasticNet, Lasso
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.kernel_ridge import KernelRidge
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import RobustScaler
from sklearn.model_selection import train_test_split, cross_val_score, KFold
from sklearn.metrics import mean_squared_error
import xgboost as xgb
import lightgbm as lgb

# %%
def rmse_cv(model):
    kf = KFold(5, shuffle=True,random_state=42).get_n_splits(train.values)
    rmse = np.sqrt(-cross_val_score(model, train.values, y_train, scoring='neg_mean_squared_error', cv = kf))
    return (rmse)

# %%
# Lasso Regression
# This model can be sensitive to outliers. That's why we use Robustscaler()
lasso = make_pipeline(RobustScaler(),Lasso(alpha=0.0005,random_state=1))

# %%
# Elastic Net Regression, an alternative to Lasso
ENet= make_pipeline(RobustScaler(),ElasticNet(alpha=0.0005, l1_ratio=0.9, random_state=3))

# %%
KRR = KernelRidge(alpha=0.6,kernel='polynomial',degree=2,coef0=2.5)

# %%
GBoost = GradientBoostingRegressor(n_estimators=1000, learning_rate=0.05, random_state=5)

# %%
model_xgb = xgb.XGBRegressor(n_estimators=1000, learning_rate=0.05, random_state=7)

# %%
model_lgb = lgb.LGBMRegressor(objective='regression', learning_rate=0.05, n_estimators=1000)

# %%
print(f'Lasso score: {round(rmse_cv(lasso).mean(),4)} ({round(rmse_cv(lasso).std(), 4)})')
# Out:
# Lasso score: 0.1116 (0.0066)

# %%
print(f'ElasticNet score: {round(rmse_cv(ENet).mean(),4)} ({round(rmse_cv(ENet).std(), 4)})')
# Out:
# ElasticNet score: 0.1116 (0.0067)

# %%
print(f'Kernel Ridge score: {round(rmse_cv(KRR).mean(),4)} ({round(rmse_cv(KRR).std(), 4)})')
# Out:
# Kernel Ridge score: 0.7447 (0.4052)

# %%
print(f'Gradient Boosting score: {round(rmse_cv(GBoost).mean(),4)} ({round(rmse_cv(GBoost).std(), 4)})')
# Out:
# Gradient Boosting score: 0.1179 (0.0067)

# %%
print(f'Xgboost score: {round(rmse_cv(model_xgb).mean(),4)} ({round(rmse_cv(model_xgb).std(), 4)})')
# Out:
# Xgboost score: 0.1214 (0.006)

# %%
print(f'Lgb score: {round(rmse_cv(model_lgb).mean(),4)} ({round(rmse_cv(model_lgb).std(), 4)})')
# Out:
# Lgb score: 0.1272 (0.0073)

# %%
X_train, X_val, y_train, y_val = train_test_split(train, y_train, test_size=0.3, random_state=42)

# %%
model_xgb.fit(X_train,y_train)
xgb_tr_pred = model_xgb.predict(X_val)
xgb_test_pred = np.exp(model_xgb.predict(test))

# %%
print(np.sqrt(mean_squared_error(y_val, xgb_tr_pred)))
# Out:
# 0.12562183750064407

# %%
lasso.fit(X_train,y_train)
lasso_tr_pred = lasso.predict(X_val)
laso_test_pred = np.exp(lasso.predict(test))
print(np.sqrt(mean_squared_error(y_val, lasso_tr_pred)))
# Out:
# 0.11524306478028395

# %%
ENet.fit(X_train,y_train)
ENet_tr_pred = ENet.predict(X_val)
ENet_test_pred = np.exp(ENet.predict(test))
print(np.sqrt(mean_squared_error(y_val, ENet_tr_pred)))
# Out:
# 0.11485283635698916

# %%
# Since ENet has a best score, we will use it as our model for prediction.
submission = pd.DataFrame({'Id': test_id, 'SalePrice': ENet_test_pred})

# %%
submission
# Out:
#         Id      SalePrice
# 0     1461  112324.753276
# 1     1462  118228.123668
# 2     1463  181125.256727
# 3     1464  201664.251901
# 4     1465  193792.658802
# ...    ...            ...
# 1454  2915   91739.580637
# 1455  2916   88767.077503
# 1456  2917  165339.643639
# 1457  2918  117866.421588
# 1458  2919  238660.844566
#
# [1459 rows x 2 columns]

# %%
submission.to_csv('submission_v1.csv', index = False)
